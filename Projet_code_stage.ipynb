# %% [markdown]
# <a href="https://colab.research.google.com/github/AurelienMoulinet/AurelienMoulinet/blob/main/Projet_code_stage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def Pythagore():
    TheoReci = input("Bonjour, voulez-vous choisir le Théorème ou la Réciproque de Pythagore ? Répondez par 't' ou 'r'. ")
 #Theoreme ou Réciproque
    while TheoReci != 't' and TheoReci != 'r':
        print("Réponse invalide. Veuillez répondre en 't' ou 'r'. ")
        TheoReci = input("Bonjour, voulez-vous choisir le Théorème ou la Réciproque de Pythagore ? Répondez par 't' ou 'r'. ")

    #Theoreme
    if TheoReci == 't':
        Theoreme = input("Recherches tu l'hypoténuse ? Réponds en oui ou non : ")

        while Theoreme != "oui" and Theoreme != "non" :
          print("Réponse invalide. Veuillez répondre en oui ou non. ")
        Theoreme = input("Recherches tu l'hypoténuse ? Réponds en oui ou non : ")

    #recherche Hypoténuse
        if Theoreme == "oui":

          a = float(input("La longueur du premier côté de l'angle droit : "))
          a = int(a)
          while  a<= 0 :
            print("Réponse invalide. A doit être positif ")
            a = float(input("La longueur du premier côté de l'angle droit : (cette fois utilisez un nombre positif SVP)"))
            a = int(a)

            b = float(input("La longueur du deuxième côté de l'angle droit : "))
            b = int(b)
            while  b<= 0 :
              print("Réponse invalide. B doit être positif ")
              b = float(input("La longueur du deuxième côté de l'angle droit : (cette fois utilise un nombre positif SVP)"))
              b = int(b)

              d  = (a * a) + (b * b)
              c = math.sqrt(d)
              c = str(c)
            return("D'après le théorème de Pythagore, la longueur de l'hypoténuse est égale à "+ c)
    #recherche côté
        elif Theoreme == "non" :
          a = float(input("La longueur du côté de l'angle droit connu : "))
          a = int(a)
        while  a<= 0 :
          print("Réponse invalide. A doit être positif ")
          a = float(input("La longueur du premier côté de l'angle droit : (cette fois utilisez un nombre positif SVP)"))
          a = int(a)

          c = float(input("La longueur de l'hypothénuse : "))
          c = int(c)
        while  c<= 0 :
          print("Réponse invalide. A doit être positif ")
          c = input("La longueur du premier côté de l'angle droit : (cette fois utilise un nombre positif SVP)")
          c = int(c)

        while a>= c :
          print("Impossible : la longueur de l'hypoténuse est trop courte par rapport au côté connu.")
          a = input("La longueur du côté de l'angle droit connu : ")
          a = int(a)

        while a<= 0 :
          print("Réponse invalide. A doit être positif ")
          a = input("La longueur du premier côté de l'angle droit : (cette fois utilise un nombre positif SVP)")
          a = int(a)

        else :
            c = input("La longueur de l'hypothénuse : ")
            c = int(c)

        while c<= 0 :
          print("Réponse invalide. A doit être positif ")
          c = input("La longueur du premier côté de l'angle droit : (cette fois utilise un nombre positif SVP)")
          c = int(c)

        else :
          d = (c**2)-(a**2)

          b = math.sqrt(d)
          b = str(b)
          print("D'après le théorème de Pythagore, la longueur de l'autre côté de l'angle droit est égale à " + str(b))


 #Reciproque
    elif TheoReci == 'r':
      print("Pouvez vous me donnez les 3 valeurs du triangles")

    c = float(input("La longueur de l'hypoténuse : "))
    c = int(c)
    #nombre négatif
    while  c<= 0 :
            print("Réponse invalide. L'hypoténuse doit être positive ")
            c = float(input("La longueur de l'hypoténuse : (cette fois utilisez un nombre positif SVP)"))
            c = int(c)


    a = float(input("La longueur du premier côté : "))
    a = int(a)


    #nombre négatif a
    while a<= 0 :
            print("Réponse invalide. A doit être positif ")
            a = float(input("La longueur du premier côté : (cette fois utilisez un nombre positif SVP)"))
            a = int(a)
#infériorité d'un coté
    while a>= c :
          print("Impossible : La première longueur est supérieur à la longueur de l'hypoténuse .")
          a = float(input("La longueur du premier côté : "))
          a = int(a)


    b = float(input("La longueur du deuxième côté : "))
    b = int(b)

    #infériorité d'un coté

    while b>= c :
          print("Impossible : La deuxième longueur est supérieur à la longueur de l'hypoténuse .")
          b = float(input("La longueur du deuxième côté : "))
          b = int(b)

    #nombre négatif
    while  b<= 0 :
            print("Réponse invalide. B doit être positif ")
            b = float(input("La longueur du deuxième côté : (cette fois utilisez un nombre positif SVP)"))
            b = int(b)



    if a**2 + b**2 == c**2:
            print("L'égalité est vérifiée, donc d'après la réciproque du théorème de Pythagore, les longueurs fournies forment un triangle rectangle.")
    else:
            print("L'égalité n'est pas vérifiée, donc les longueurs fournies ne forment pas un triangle rectangle d'après la réciproque du théorème de Pythagore.")

# Appel de la fonction

# %%
c = 5
a = 4
d = (c**2)-(a**2)
e = math.sqrt(d)

e
# Out:
# 3.0

# %%
Pythagore ()

# %%
import math

def Test_Pythagore():
    TheoReci = input("Bonjour, voulez-vous choisir le Théorème ou la Réciproque de Pythagore ? Répondez par 't' ou 'r'. ")

    # Théorème ou Réciproque
    while TheoReci != 't' and TheoReci != 'r':
        print("Réponse invalide. Veuillez répondre en 't' ou 'r'. ")
        TheoReci = input("Bonjour, voulez-vous choisir le Théorème ou la Réciproque de Pythagore ? Répondez par 't' ou 'r'. ")

    # Théorème
    if TheoReci == 't':
        Theoreme = input("Recherches-tu l'hypoténuse ? Réponds par oui ou non : ")

        while Theoreme != "oui" and Theoreme != "non" :
            print("Réponse invalide. Veuillez répondre par oui ou non. ")
            Theoreme = input("Recherches-tu l'hypoténuse ? Réponds par oui ou non : ")

        # Recherche Hypoténuse
        if Theoreme == "oui":
            a = float(input("La longueur du premier côté de l'angle droit : "))
            while a <= 0:
                print("Réponse invalide. A doit être positif ")
                a = float(input("La longueur du premier côté de l'angle droit : (cette fois utilisez un nombre positif SVP)"))

            b = float(input("La longueur du deuxième côté de l'angle droit : "))
            while b <= 0:
                print("Réponse invalide. B doit être positif ")
                b = float(input("La longueur du deuxième côté de l'angle droit : (cette fois utilisez un nombre positif SVP)"))

            c = math.sqrt(a**2 + b**2)
            print(f"D'après le théorème de Pythagore, la longueur de l'hypoténuse est égale à {c}")

        # Recherche côté
        elif Theoreme == "non":
            a = float(input("La longueur du côté de l'angle droit connu : "))
            while a <= 0:
                print("Réponse invalide. A doit être positif ")
                a = float(input("La longueur du premier côté de l'angle droit : (cette fois utilisez un nombre positif SVP)"))

            c = float(input("La longueur de l'hypoténuse : "))
            while c <= 0 or c <= a:
                if c <= 0:
                    print("Réponse invalide. La longueur de l'hypoténuse doit être positive.")
                else:
                    print("Impossible : la longueur de l'hypoténuse est trop courte par rapport au côté connu.")

                c = float(input("La longueur de l'hypoténuse : "))

            b = math.sqrt(c**2 - a**2)
            print(f"D'après le théorème de Pythagore, la longueur de l'autre côté de l'angle droit est égale à {b}")

    # Réciproque
    elif TheoReci == 'r':
        print("Pouvez-vous me donner les 3 valeurs du triangle")

        c = float(input("La longueur de l'hypoténuse : "))
        while c <= 0:
            print("Réponse invalide. L'hypoténuse doit être positive ")
            c = float(input("La longueur de l'hypoténuse : (cette fois utilisez un nombre positif SVP)"))

        a = float(input("La longueur du premier côté : "))
        while a <= 0:
            print("Réponse invalide. A doit être positif ")
            a = float(input("La longueur du premier côté : (cette fois utilisez un nombre positif SVP)"))

        while a >= c:
            print("Impossible : La première longueur est supérieure à la longueur de l'hypoténuse.")
            a = float(input("La longueur du premier côté : "))

        b = float(input("La longueur du deuxième côté : "))
        while b >= c:
            print("Impossible : La deuxième longueur est supérieure à la longueur de l'hypoténuse.")
            b = float(input("La longueur du deuxième côté : "))
        while b <= 0:
            print("Réponse invalide. B doit être positif ")
            b = float(input("La longueur du deuxième côté : (cette fois utilisez un nombre positif SVP)"))

        if a**2 + b**2 == c**2:
            print("L'égalité est vérifiée, donc d'après la réciproque du théorème de Pythagore, les longueurs fournies forment un triangle rectangle.")
        else:
            print("L'égalité n'est pas vérifiée, donc les longueurs fournies ne forment pas un triangle rectangle d'après la réciproque du théorème de Pythagore.")

# Appel de la fonction
Test_Pythagore()

# %%
Test_Pythagore()
# Out:
# Bonjour, voulez-vous choisir le Théorème ou la Réciproque de Pythagore ? Répondez par 't' ou 'r'. t
# Recherches-tu l'hypoténuse ? Réponds par oui ou non : non
# La longueur du côté de l'angle droit connu : 3
# La longueur de l'hypoténuse : 1
# Impossible : la longueur de l'hypoténuse est trop courte par rapport au côté connu.
# La longueur de l'hypoténuse : -6
# Réponse invalide. La longueur de l'hypoténuse doit être positive.
# La longueur de l'hypoténuse : -1
# Réponse invalide. La longueur de l'hypoténuse doit être positive.
# La longueur de l'hypoténuse : 2
# Impossible : la longueur de l'hypoténuse est trop courte par rapport au côté connu.
# La longueur de l'hypoténuse : 3
# Impossible : la longueur de l'hypoténuse est trop courte par rapport au côté connu.
# La longueur de l'hypoténuse : 6
# D'après le théorème de Pythagore, la longueur de l'autre côté de l'angle droit est égale à 5.196152422706632
